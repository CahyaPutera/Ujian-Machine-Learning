# %% [markdown]
# # Ujian Modul 2 - Purwadhika Data Science JC Program
#
# ## Context - Taken from Kaggle
# Did you know that claims can be filed against TSA? Sometimes US Terminal Security Agency (TSA) makes mistakes. People can get hurt and property can be damaged, lost, or stolen. Claims are generally filed against TSA for personal injuries and lost or damaged property during screenings and they keep records of every claim!
#
# ### Content
# The dataset includes claims filed between 2002 through 2015.
#
# 1. Claim Number
# 1. Date Received
# 1. Incident Date
# 1. Airport Code
# 1. Airport Name
# 1. Airline Name
# 1. Claim Type
# 1. Claim Site
# 1. Item
# 1. Claim Amount
# 1. Status
# 1. Close Amount
# 1. Disposition
#
# This data is coming from the Kaggle Dataset that contain the data of clain the been filed into the TSA. We would try to explore the data and clean the data partially (we would not clean and analyze everything as it would take more time than necessary) and we would only use 25% data from the original dataset.
#
# This exam scoring would be explained below:
#
# - This Notebook would have total score of 80 (+ 10 Bonus POINT for Bonus Question), which consist of:
#     - 40 POINT for the Question part (10 point for each question)
#     - 40 POINT for the preprocessing part by following the guide
# - The Dashboard would yield 20 POINT
# - The Maximum Score would be still 100, Bonus Question is just a Bonus. Work it if you have an extra time and already sure about all your other answer (or not sure about the other question, and need this bonus question to help)
#
# When you finish, upload your notebook contain all the answers and the script for the dashboard to your github. You do not need to upload the .csv file.

# %% [markdown]
# Try to read the data and show all the important info first. For starter, try to understand what each column represent.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
tsa_data = pd.read_csv('tsa_claims_ujian.csv')

# %%
tsa_data.head()
# Out:
#   Claim Number Date Received   Incident Date Airport Code  \
# 0     0909816M      7-Feb-02   1/6/2003 0:00          MIA
# 1        14268     20-Jun-02  6/16/2002 0:00          PHX
# 2        15242     12-Jul-02  5/31/2002 0:00          BWI
# 3        16759     21-Aug-02  7/12/2002 0:00          BWI
# 4        17846      9-Sep-02  8/30/2002 0:00          BOS
#
#                                   Airport Name        Airline Name  \
# 0                  Miami International Airport   American Airlines
# 1             Phoenix Sky Harbor International                 NaN
# 2  Baltimore/Washington Intl Thurgood Marshall   American Airlines
# 3  Baltimore/Washington Intl Thurgood Marshall  Southwest Airlines
# 4         Boston (Logan) International Airport                 NaN
#
#                 Claim Type  Claim Site  \
# 0          Property Damage  Checkpoint
# 1          Property Damage  Checkpoint
# 2                      NaN       Other
# 3  Passenger Property Loss  Checkpoint
# 4          Property Damage  Checkpoint
#
#                                         Item Claim Amount    Status  \
# 0  Luggage (all types including footlockers)      $50.00   Approved
# 1                          Computer - Laptop   $2;270.09   Canceled
# 2  Luggage (all types including footlockers)     $200.00     Denied
# 3                                      Other      $21.44   Approved
# 4  Luggage (all types including footlockers)   $1;832.22   Canceled
#
#   Close Amount      Disposition
# 0      $50.00   Approve in Full
# 1          NaN              NaN
# 2       $0.00              Deny
# 3      $21.00   Approve in Full
# 4       $0.00               NaN

# %%
tsa_data.tail()
# Out:
#         Claim Number Date Received Incident Date Airport Code Airport Name  \
# 51061  2015110926685     22-Oct-15     19-Oct-15            -            -
# 51062  2015110226479      2-Nov-15      2-Nov-15            -            -
# 51063  2015120727336     16-Nov-15     14-Sep-15            -            -
# 51064  2015120427297     20-Nov-15     16-Oct-15            -            -
# 51065  2016010428072     22-Dec-15     20-Dec-15            -            -
#
#             Airline Name               Claim Type       Claim Site  \
# 51061                  -          Property Damage  Checked Baggage
# 51062                  -  Passenger Property Loss       Checkpoint
# 51063  American Airlines  Passenger Property Loss  Checked Baggage
# 51064                  -          Property Damage  Checked Baggage
# 51065                  -  Passenger Property Loss  Checked Baggage
#
#                                                     Item Claim Amount Status  \
# 51061                               Baggage/Cases/Purses            -      -
# 51062                           Books; Magazines & Other            -      -
# 51063                               Cosmetics & Grooming            -      -
# 51064  Baggage/Cases/Purses; Books; Magazines & Other...            -      -
# 51065                                           Clothing            -      -
#
#       Close Amount Disposition
# 51061          NaN         NaN
# 51062          NaN         NaN
# 51063          NaN         NaN
# 51064          NaN         NaN
# 51065          NaN         NaN

# %%
tsa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51066 entries, 0 to 51065
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Claim Number   51066 non-null  object
#  1   Date Received  50996 non-null  object
#  2   Incident Date  50496 non-null  object
#  3   Airport Code   49014 non-null  object
#  4   Airport Name   49014 non-null  object
#  5   Airline Name   42511 non-null  object
#  6   Claim Type     49106 non-null  object
#  7   Claim Site     50876 non-null  object
#  8   Item           50054 non-null  object
#  9   Claim Amount   50074 non-null  object
#  10  Status         51065 non-null  object
#  11  Close Amount   33786 non-null  object
#  12  Disposition    32846 non-null  object
# dtypes: object(13)
# memory usage: 5.1+ MB

# %%
tsa_data.describe()
# Out:
#          Claim Number Date Received    Incident Date Airport Code  \
# count           51066         50996            50496        49014
# unique          51065          3522            10788          405
# top     2013121110011     27-May-04  12/22/2004 0:00          LAX
# freq                2           182               43         2379
#
#                          Airport Name       Airline Name  \
# count                           49014              42511
# unique                            419                243
# top     John F. Kennedy International  American Airlines
# freq                             2286               4377
#
#                      Claim Type       Claim Site   Item Claim Amount  Status  \
# count                     49106            50876  50054        50074   51065
# unique                        8                6   1854        13248      13
# top     Passenger Property Loss  Checked Baggage  Other       $0.00   Denied
# freq                      29713            39937   9183         7065   17134
#
#        Close Amount Disposition
# count         33786       32846
# unique         6009           3
# top          $0.00         Deny
# freq          17907       17147

# %%
tsa_data_features = pd.DataFrame({'dataFeatures' : tsa_data.columns, 
                                  'dataType' : tsa_data.dtypes, 
                                  'null' : np.sum(tsa_data.isna()), 
                                  'nullPct' : round(np.sum(tsa_data.isna())/len(tsa_data)*100,2), 
                                  'unique' : tsa_data.nunique(), 
                                  'uniqueSample' : [list(tsa_data[i].drop_duplicates().sample(2))for i in tsa_data.columns]}).reset_index(drop = True)

# %%
tsa_data_features
# Out:
#      dataFeatures dataType   null  nullPct  unique  \
# 0    Claim Number   object      0     0.00   51065
# 1   Date Received   object     70     0.14    3522
# 2   Incident Date   object    570     1.12   10788
# 3    Airport Code   object   2052     4.02     405
# 4    Airport Name   object   2052     4.02     419
# 5    Airline Name   object   8555    16.75     243
# 6      Claim Type   object   1960     3.84       8
# 7      Claim Site   object    190     0.37       6
# 8            Item   object   1012     1.98    1854
# 9    Claim Amount   object    992     1.94   13248
# 10         Status   object      1     0.00      13
# 11   Close Amount   object  17280    33.84    6009
# 12    Disposition   object  18220    35.68       3
#
#                                          uniqueSample
# 0                      [2005092193044, 2009032556867]
# 1                              [21-Aug-09, 19-Dec-14]
# 2                   [6/18/2008 0:00, 10/20/2007 0:00]
# 3                                          [FNT, PGV]
# 4   [Northwest Florida Beaches International Airpo...
# 5   [Westjet Airlines Ltd, Pacific Southwest Airli...
# 6                                [nan, Motor Vehicle]
# 7                        [Motor Vehicle, Bus Station]
# 8   [Cosmetics & Grooming; Jewelry & Watches; Jewe...
# 9                              [$1;756.05 , $521.54 ]
# 10                              [Deny, Claim entered]
# 11                               [$208.88 , $162.90 ]
# 12                             [Approve in Full, nan]

# %% [markdown]
# If you notice, there is '-' value that become a filler for an empty value. Replace all these '-' in every column into NaN object (np.nan)

# %%
tsa_data.replace({'-': np.nan}, inplace=True)

# %% [markdown]
# Try to convert the Date Received and Incident Date data type into Datetime object. For the Incident Date columns, if you directly try to convert the column into datetime object it would raise an error notice. In that case, try to show the dataframe with the Incident Date column contain all the error.

# %%
tsa_data['Date Received'] = pd.to_datetime(tsa_data['Date Received'])

# %%
error = []
for i, j in enumerate(tsa_data['Incident Date']):
    try :
        pd.to_datetime(j)
    except :
        error.append(i)

# %%
tsa_data.loc[error]
# Out:
#         Claim Number Date Received      Incident Date Airport Code  \
# 13729  2005021676300    2005-01-24  17-MAY-0200 00:00          JFK
# 14323  2005031778682    2005-02-23  17-FEB-0205 00:00          MSY
# 14856  2005033180821    2005-03-23  07-MAR-0005 00:00          CVG
# 14976  2005040181143    2005-03-29  04-MAR-0205 00:00          MSP
# 14995  2005040581540    2005-03-30  18-MAR-0200 00:00          MAF
# 15278  2005041282328    2005-04-12  12-MAR-0205 00:00          MSP
# 15934  2005051985030    2005-05-17  01-MAY-0205 00:00          NaN
# 16813  2005071188622    2005-07-08  01-JUL-0200 00:00          HDN
# 17198  2005091492472    2005-08-01  01-MAY-0205 00:00          IAH
# 19151  2005121397614    2005-12-08  20-NOV-0205 00:00          LNK
# 21528  2006060207211    2006-05-30  26-MAY-0200 00:00          JFK
# 22161  2006072610104    2006-07-14  25-OCT-0200 00:00          MEM
# 23232  2006101213887    2006-10-11  27-SEP-0206 00:00          JFK
# 24355  2007010418246    2007-01-03  03-NOV-0206 00:00          OMA
# 24525  2007011718892    2007-01-10  12-AUG-0201 00:00          JFK
# 24768  2007013119947    2007-01-26  19-DEC-0206 00:00          PHX
# 24903  2007020620372    2007-02-05  13-JAN-0207 00:00          JFK
# 25249  2007031222075    2007-03-06  18-FEB-0207 00:00          SEA
# 25705  2007041323942    2007-04-10  07-APR-0200 00:00          IAD
# 25734  2007041323952    2007-04-12  29-JAN-0200 00:00          SAN
# 26129  2007051825607    2007-05-16  06-MAR-0207 00:00          BPT
# 26530  2007062127333    2007-06-19  20-MAY-0207 00:00          FLL
# 27086  2007073129436    2007-07-31  13-JUL-0207 00:00          IND
# 27481  2007083131244    2007-08-28  09-JUL-0200 00:00          MSP
# 27628  2007091431890    2007-09-10  02-MAR-0208 00:00          MDW
# 27819  2007092732635    2007-09-24  17-SEP-0007 00:00          DTW
# 27901  2007100533098    2007-10-02  22-MAY-0200 00:00          RSW
# 28031  2007101733560    2007-10-12  28-SEP-0207 00:00          ATL
# 28037  2007101833587    2007-10-12  04-SEP-0207 00:00          MIA
# 29065  2008011437819    2008-01-07  30-NOV-0002 00:00          RAP
# 29652  2008022840321    2008-02-22  08-FEB-0208 00:00          AVL
# 31140  2008062646202    2008-06-23  29-JAN-0208 00:00          MIA
# 31570  2008080548050    2008-07-31  30-JUL-0208 00:00          HOU
# 31590  2008081148331    2008-08-01  13-JUL-0200 00:00          ATL
# 31771  2008081948782    2008-08-19  23-JUL-0208 00:00          FLL
# 33613  2009032056617    2009-03-04  18-JAN-0200 00:00          FLL
#
#                                            Airport Name  \
# 13729                     John F. Kennedy International
# 14323                         New Orleans International
# 14856        Cincinnati/Northern Kentucky International
# 14976        Minneapolis/ St.Paul International Airport
# 14995                     Midland International Airport
# 15278        Minneapolis/ St.Paul International Airport
# 15934                                               NaN
# 16813                             Yampa Valley Regional
# 17198    Houston - George Bush Intercontinental Airport
# 19151                                 Lincoln Municipal
# 21528                     John F. Kennedy International
# 22161                     Memphis International Airport
# 23232                     John F. Kennedy International
# 24355                                   Eppley Airfield
# 24525                     John F. Kennedy International
# 24768                  Phoenix Sky Harbor International
# 24903                     John F. Kennedy International
# 25249                      Seattle-Tacoma International
# 25705                   Washington Dulles International
# 25734                           San Diego International
# 26129                          Southeast Texas Regional
# 26530            Ft. Lauderdale-Hollywood International
# 27086                        Indianapolis International
# 27481        Minneapolis/ St.Paul International Airport
# 27628                      Midway International Airport
# 27819         Detroit Metropolitan Wayne County Airport
# 27901                   Southwest Florida International
# 28031  Hartsfield-Jackson Atlanta International Airport
# 28037                       Miami International Airport
# 29065                               Rapid City Regional
# 29652                        Asheville Regional Airport
# 31140                       Miami International Airport
# 31570                                  William P. Hobby
# 31590  Hartsfield-Jackson Atlanta International Airport
# 31771            Ft. Lauderdale-Hollywood International
# 33613            Ft. Lauderdale-Hollywood International
#
#                    Airline Name               Claim Type       Claim Site  \
# 13729                       NaN  Passenger Property Loss       Checkpoint
# 14323                       UAL  Passenger Property Loss  Checked Baggage
# 14856           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 14976        Northwest Airlines  Passenger Property Loss  Checked Baggage
# 14995   Continental Express Inc  Passenger Property Loss  Checked Baggage
# 15278        Northwest Airlines          Property Damage  Checked Baggage
# 15934                       NaN  Passenger Property Loss  Checked Baggage
# 16813                       NaN  Passenger Property Loss  Checked Baggage
# 17198                       UAL  Passenger Property Loss  Checked Baggage
# 19151        Northwest Airlines  Passenger Property Loss  Checked Baggage
# 21528                Air France  Passenger Property Loss  Checked Baggage
# 22161        Northwest Airlines  Passenger Property Loss  Checked Baggage
# 23232      Continental Airlines  Passenger Property Loss       Checkpoint
# 24355  Skywest Airlines Inc USA  Passenger Property Loss  Checked Baggage
# 24525                  Jet Blue  Passenger Property Loss  Checked Baggage
# 24768        Northwest Airlines          Property Damage  Checked Baggage
# 24903                  Jet Blue  Passenger Property Loss  Checked Baggage
# 25249           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 25705                       UAL  Passenger Property Loss  Checked Baggage
# 25734        Southwest Airlines  Passenger Property Loss  Checked Baggage
# 26129      Continental Airlines  Passenger Property Loss  Checked Baggage
# 26530           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 27086        Northwest Airlines          Property Damage  Checked Baggage
# 27481        Northwest Airlines          Property Damage  Checked Baggage
# 27628        Southwest Airlines          Property Damage  Checked Baggage
# 27819        Northwest Airlines  Passenger Property Loss  Checked Baggage
# 27901           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 28031           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 28037         American Airlines  Passenger Property Loss  Checked Baggage
# 29065        Northwest Airlines  Passenger Property Loss  Checked Baggage
# 29652           Delta Air Lines          Property Damage  Checked Baggage
# 31140         American Airlines          Property Damage  Checked Baggage
# 31570      Continental Airlines  Passenger Property Loss  Checked Baggage
# 31590           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 31771                  Jet Blue  Passenger Property Loss  Checked Baggage
# 33613         American Airlines          Property Damage       Checkpoint
#
#                                                     Item Claim Amount  \
# 13729                                              Other      $15.00
# 14323                                  Computer - Laptop   $2;463.00
# 14856                                  Cameras - Digital     $430.98
# 14976                                     Jewelry - Fine     $151.00
# 14995                                              Locks      $10.60
# 15278         Clothing - Shoes; belts; accessories; etc.     $710.00
# 15934                                     Jewelry - Fine     $197.73
# 16813         Clothing - Shoes; belts; accessories; etc.     $300.00
# 17198                                              Other   $2;000.72
# 19151                                              Locks      $15.00
# 21528  Cosmetics - Perfume; toilet articles; medicine...     $821.56
# 22161                                        Cell Phones      $35.00
# 23232                                              Other      $25.49
# 24355                                  Jewelry - Costume     $135.00
# 24525              Video Recordings (blank & commercial)     $317.64
# 24768                                              Other      $90.00
# 24903                                  Computer - Laptop   $1;503.35
# 25249  Clothing - Shoes; belts; accessories; etc.; Other     $190.00
# 25705                           Cameras - Digital; Other     $470.06
# 25734                           MP3 Players-(iPods; etc)     $250.00
# 26129  Cameras - Digital; Cameras - Non-electronic (C...   $1;400.25
# 26530  Cosmetics - Perfume; toilet articles; medicine...      $10.00
# 27086                        Baskets - Wicker or plastic      $15.00
# 27481          Luggage (all types including footlockers)     $185.00
# 27628  Clothing - Shoes; belts; accessories; etc.; Pa...     $250.00
# 27819                                           Currency     $420.00
# 27901                                           Currency     $100.00
# 28031  Cosmetics - Perfume; toilet articles; medicine...     $109.99
# 28037                                              Other      $69.95
# 29065  Clothing - Shoes; belts; accessories; etc.; Lu...     $200.00
# 29652                         Mirrors (including frames)      $21.93
# 31140                                              Locks       $5.98
# 31570                                              Locks      $16.00
# 31590  Cosmetics - Perfume; toilet articles; medicine...      $40.00
# 31771  Computer - Laptop; GPS - Global Positioning Sy...   $3;379.00
# 33613            Eyeglasses - (including contact lenses)     $469.00
#
#                                                   Status Close Amount  \
# 13729                                           Approved      $15.00
# 14323                                             Denied          NaN
# 14856                                           Approved     $430.98
# 14976  Insufficient; one of the following items requi...          NaN
# 14995                                           Approved      $10.60
# 15278                                             Denied       $0.00
# 15934  Insufficient; one of the following items requi...          NaN
# 16813                                             Denied       $0.00
# 17198                                             Denied       $0.00
# 19151                                           Approved      $15.00
# 21528                                            Settled     $261.72
# 22161                                             Denied       $0.00
# 23232                                           Approved      $25.49
# 24355                                             Denied       $0.00
# 24525                                            Settled     $158.82
# 24768                                             Denied       $0.00
# 24903                                            Settled     $208.47
# 25249                                             Denied       $0.00
# 25705                                            Settled     $198.09
# 25734                                             Denied       $0.00
# 26129                                             Denied       $0.00
# 26530                                           Approved      $10.00
# 27086                                             Denied       $0.00
# 27481                                            Settled      $50.00
# 27628                                             Denied       $0.00
# 27819                                             Denied       $0.00
# 27901                                             Denied       $0.00
# 28031                                             Denied       $0.00
# 28037                                             Denied       $0.00
# 29065                                             Denied       $0.00
# 29652                                             Denied       $0.00
# 31140                                             Denied       $0.00
# 31570                                             Denied       $0.00
# 31590                                             Denied       $0.00
# 31771                                             Denied       $0.00
# 33613                                             Denied       $0.00
#
#            Disposition
# 13729  Approve in Full
# 14323             Deny
# 14856  Approve in Full
# 14976              NaN
# 14995  Approve in Full
# 15278             Deny
# 15934              NaN
# 16813             Deny
# 17198             Deny
# 19151  Approve in Full
# 21528           Settle
# 22161             Deny
# 23232  Approve in Full
# 24355             Deny
# 24525           Settle
# 24768             Deny
# 24903           Settle
# 25249             Deny
# 25705           Settle
# 25734             Deny
# 26129             Deny
# 26530  Approve in Full
# 27086             Deny
# 27481           Settle
# 27628             Deny
# 27819             Deny
# 27901             Deny
# 28031             Deny
# 28037             Deny
# 29065             Deny
# 29652             Deny
# 31140             Deny
# 31570             Deny
# 31590             Deny
# 31771             Deny
# 33613             Deny

# %% [markdown]
# For the data in the Incident Date column that contain error, replace the year with the year that come from the Date Received column and replace the Incident Date data type into datetime object

# %%
def incidentError(dat):
    try:
        dat['Incident Date'] = pd.to_datetime(dat['Incident Date'])
        return dat
    except:
        dat['Incident Date'] = pd.to_datetime(dat['Incident Date'][0:7] + str(dat['Date Received'].year))
        return dat

# %%
tsa_data[['Date Received','Incident Date']] = tsa_data[['Date Received','Incident Date']].apply(incidentError,axis=1)

# %% [markdown]
# Check the data info and the dataframe that previously contain the error in their data to see if the data have been properly corrected.

# %%
tsa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51066 entries, 0 to 51065
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Claim Number   51066 non-null  object
#  1   Date Received  50996 non-null  datetime64[ns]
#  2   Incident Date  50496 non-null  datetime64[ns]
#  3   Airport Code   48915 non-null  object
#  4   Airport Name   48915 non-null  object
#  5   Airline Name   41470 non-null  object
#  6   Claim Type     49035 non-null  object
#  7   Claim Site     50817 non-null  object
#  8   Item           48918 non-null  object
#  9   Claim Amount   46886 non-null  object
#  10  Status         47877 non-null  object
#  11  Close Amount   33786 non-null  object
#  12  Disposition    32846 non-null  object
# dtypes: datetime64[ns](2), object(11)
# memory usage: 5.1+ MB

# %%
tsa_data.loc[error]
# Out:
#         Claim Number Date Received Incident Date Airport Code  \
# 13729  2005021676300    2005-01-24    2005-05-17          JFK
# 14323  2005031778682    2005-02-23    2005-02-17          MSY
# 14856  2005033180821    2005-03-23    2005-03-07          CVG
# 14976  2005040181143    2005-03-29    2005-03-04          MSP
# 14995  2005040581540    2005-03-30    2005-03-18          MAF
# 15278  2005041282328    2005-04-12    2005-03-12          MSP
# 15934  2005051985030    2005-05-17    2005-05-01          NaN
# 16813  2005071188622    2005-07-08    2005-07-01          HDN
# 17198  2005091492472    2005-08-01    2005-05-01          IAH
# 19151  2005121397614    2005-12-08    2005-11-20          LNK
# 21528  2006060207211    2006-05-30    2006-05-26          JFK
# 22161  2006072610104    2006-07-14    2006-10-25          MEM
# 23232  2006101213887    2006-10-11    2006-09-27          JFK
# 24355  2007010418246    2007-01-03    2007-11-03          OMA
# 24525  2007011718892    2007-01-10    2007-08-12          JFK
# 24768  2007013119947    2007-01-26    2007-12-19          PHX
# 24903  2007020620372    2007-02-05    2007-01-13          JFK
# 25249  2007031222075    2007-03-06    2007-02-18          SEA
# 25705  2007041323942    2007-04-10    2007-04-07          IAD
# 25734  2007041323952    2007-04-12    2007-01-29          SAN
# 26129  2007051825607    2007-05-16    2007-03-06          BPT
# 26530  2007062127333    2007-06-19    2007-05-20          FLL
# 27086  2007073129436    2007-07-31    2007-07-13          IND
# 27481  2007083131244    2007-08-28    2007-07-09          MSP
# 27628  2007091431890    2007-09-10    2007-03-02          MDW
# 27819  2007092732635    2007-09-24    2007-09-17          DTW
# 27901  2007100533098    2007-10-02    2007-05-22          RSW
# 28031  2007101733560    2007-10-12    2007-09-28          ATL
# 28037  2007101833587    2007-10-12    2007-09-04          MIA
# 29065  2008011437819    2008-01-07    2008-11-30          RAP
# 29652  2008022840321    2008-02-22    2008-02-08          AVL
# 31140  2008062646202    2008-06-23    2008-01-29          MIA
# 31570  2008080548050    2008-07-31    2008-07-30          HOU
# 31590  2008081148331    2008-08-01    2008-07-13          ATL
# 31771  2008081948782    2008-08-19    2008-07-23          FLL
# 33613  2009032056617    2009-03-04    2009-01-18          FLL
#
#                                            Airport Name  \
# 13729                     John F. Kennedy International
# 14323                         New Orleans International
# 14856        Cincinnati/Northern Kentucky International
# 14976        Minneapolis/ St.Paul International Airport
# 14995                     Midland International Airport
# 15278        Minneapolis/ St.Paul International Airport
# 15934                                               NaN
# 16813                             Yampa Valley Regional
# 17198    Houston - George Bush Intercontinental Airport
# 19151                                 Lincoln Municipal
# 21528                     John F. Kennedy International
# 22161                     Memphis International Airport
# 23232                     John F. Kennedy International
# 24355                                   Eppley Airfield
# 24525                     John F. Kennedy International
# 24768                  Phoenix Sky Harbor International
# 24903                     John F. Kennedy International
# 25249                      Seattle-Tacoma International
# 25705                   Washington Dulles International
# 25734                           San Diego International
# 26129                          Southeast Texas Regional
# 26530            Ft. Lauderdale-Hollywood International
# 27086                        Indianapolis International
# 27481        Minneapolis/ St.Paul International Airport
# 27628                      Midway International Airport
# 27819         Detroit Metropolitan Wayne County Airport
# 27901                   Southwest Florida International
# 28031  Hartsfield-Jackson Atlanta International Airport
# 28037                       Miami International Airport
# 29065                               Rapid City Regional
# 29652                        Asheville Regional Airport
# 31140                       Miami International Airport
# 31570                                  William P. Hobby
# 31590  Hartsfield-Jackson Atlanta International Airport
# 31771            Ft. Lauderdale-Hollywood International
# 33613            Ft. Lauderdale-Hollywood International
#
#                    Airline Name               Claim Type       Claim Site  \
# 13729                       NaN  Passenger Property Loss       Checkpoint
# 14323                       UAL  Passenger Property Loss  Checked Baggage
# 14856           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 14976        Northwest Airlines  Passenger Property Loss  Checked Baggage
# 14995   Continental Express Inc  Passenger Property Loss  Checked Baggage
# 15278        Northwest Airlines          Property Damage  Checked Baggage
# 15934                       NaN  Passenger Property Loss  Checked Baggage
# 16813                       NaN  Passenger Property Loss  Checked Baggage
# 17198                       UAL  Passenger Property Loss  Checked Baggage
# 19151        Northwest Airlines  Passenger Property Loss  Checked Baggage
# 21528                Air France  Passenger Property Loss  Checked Baggage
# 22161        Northwest Airlines  Passenger Property Loss  Checked Baggage
# 23232      Continental Airlines  Passenger Property Loss       Checkpoint
# 24355  Skywest Airlines Inc USA  Passenger Property Loss  Checked Baggage
# 24525                  Jet Blue  Passenger Property Loss  Checked Baggage
# 24768        Northwest Airlines          Property Damage  Checked Baggage
# 24903                  Jet Blue  Passenger Property Loss  Checked Baggage
# 25249           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 25705                       UAL  Passenger Property Loss  Checked Baggage
# 25734        Southwest Airlines  Passenger Property Loss  Checked Baggage
# 26129      Continental Airlines  Passenger Property Loss  Checked Baggage
# 26530           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 27086        Northwest Airlines          Property Damage  Checked Baggage
# 27481        Northwest Airlines          Property Damage  Checked Baggage
# 27628        Southwest Airlines          Property Damage  Checked Baggage
# 27819        Northwest Airlines  Passenger Property Loss  Checked Baggage
# 27901           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 28031           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 28037         American Airlines  Passenger Property Loss  Checked Baggage
# 29065        Northwest Airlines  Passenger Property Loss  Checked Baggage
# 29652           Delta Air Lines          Property Damage  Checked Baggage
# 31140         American Airlines          Property Damage  Checked Baggage
# 31570      Continental Airlines  Passenger Property Loss  Checked Baggage
# 31590           Delta Air Lines  Passenger Property Loss  Checked Baggage
# 31771                  Jet Blue  Passenger Property Loss  Checked Baggage
# 33613         American Airlines          Property Damage       Checkpoint
#
#                                                     Item Claim Amount  \
# 13729                                              Other      $15.00
# 14323                                  Computer - Laptop   $2;463.00
# 14856                                  Cameras - Digital     $430.98
# 14976                                     Jewelry - Fine     $151.00
# 14995                                              Locks      $10.60
# 15278         Clothing - Shoes; belts; accessories; etc.     $710.00
# 15934                                     Jewelry - Fine     $197.73
# 16813         Clothing - Shoes; belts; accessories; etc.     $300.00
# 17198                                              Other   $2;000.72
# 19151                                              Locks      $15.00
# 21528  Cosmetics - Perfume; toilet articles; medicine...     $821.56
# 22161                                        Cell Phones      $35.00
# 23232                                              Other      $25.49
# 24355                                  Jewelry - Costume     $135.00
# 24525              Video Recordings (blank & commercial)     $317.64
# 24768                                              Other      $90.00
# 24903                                  Computer - Laptop   $1;503.35
# 25249  Clothing - Shoes; belts; accessories; etc.; Other     $190.00
# 25705                           Cameras - Digital; Other     $470.06
# 25734                           MP3 Players-(iPods; etc)     $250.00
# 26129  Cameras - Digital; Cameras - Non-electronic (C...   $1;400.25
# 26530  Cosmetics - Perfume; toilet articles; medicine...      $10.00
# 27086                        Baskets - Wicker or plastic      $15.00
# 27481          Luggage (all types including footlockers)     $185.00
# 27628  Clothing - Shoes; belts; accessories; etc.; Pa...     $250.00
# 27819                                           Currency     $420.00
# 27901                                           Currency     $100.00
# 28031  Cosmetics - Perfume; toilet articles; medicine...     $109.99
# 28037                                              Other      $69.95
# 29065  Clothing - Shoes; belts; accessories; etc.; Lu...     $200.00
# 29652                         Mirrors (including frames)      $21.93
# 31140                                              Locks       $5.98
# 31570                                              Locks      $16.00
# 31590  Cosmetics - Perfume; toilet articles; medicine...      $40.00
# 31771  Computer - Laptop; GPS - Global Positioning Sy...   $3;379.00
# 33613            Eyeglasses - (including contact lenses)     $469.00
#
#                                                   Status Close Amount  \
# 13729                                           Approved      $15.00
# 14323                                             Denied          NaN
# 14856                                           Approved     $430.98
# 14976  Insufficient; one of the following items requi...          NaN
# 14995                                           Approved      $10.60
# 15278                                             Denied       $0.00
# 15934  Insufficient; one of the following items requi...          NaN
# 16813                                             Denied       $0.00
# 17198                                             Denied       $0.00
# 19151                                           Approved      $15.00
# 21528                                            Settled     $261.72
# 22161                                             Denied       $0.00
# 23232                                           Approved      $25.49
# 24355                                             Denied       $0.00
# 24525                                            Settled     $158.82
# 24768                                             Denied       $0.00
# 24903                                            Settled     $208.47
# 25249                                             Denied       $0.00
# 25705                                            Settled     $198.09
# 25734                                             Denied       $0.00
# 26129                                             Denied       $0.00
# 26530                                           Approved      $10.00
# 27086                                             Denied       $0.00
# 27481                                            Settled      $50.00
# 27628                                             Denied       $0.00
# 27819                                             Denied       $0.00
# 27901                                             Denied       $0.00
# 28031                                             Denied       $0.00
# 28037                                             Denied       $0.00
# 29065                                             Denied       $0.00
# 29652                                             Denied       $0.00
# 31140                                             Denied       $0.00
# 31570                                             Denied       $0.00
# 31590                                             Denied       $0.00
# 31771                                             Denied       $0.00
# 33613                                             Denied       $0.00
#
#            Disposition
# 13729  Approve in Full
# 14323             Deny
# 14856  Approve in Full
# 14976              NaN
# 14995  Approve in Full
# 15278             Deny
# 15934              NaN
# 16813             Deny
# 17198             Deny
# 19151  Approve in Full
# 21528           Settle
# 22161             Deny
# 23232  Approve in Full
# 24355             Deny
# 24525           Settle
# 24768             Deny
# 24903           Settle
# 25249             Deny
# 25705           Settle
# 25734             Deny
# 26129             Deny
# 26530  Approve in Full
# 27086             Deny
# 27481           Settle
# 27628             Deny
# 27819             Deny
# 27901             Deny
# 28031             Deny
# 28037             Deny
# 29065             Deny
# 29652             Deny
# 31140             Deny
# 31570             Deny
# 31590             Deny
# 31771             Deny
# 33613             Deny

# %% [markdown]
# Create a new feature of the day differences between claim received and the day of the incident called Day Differences, which contain the days that come from the Date Received column substracted by the Incident Date column (Date Received - Incident Date). We have this feature to see the time differences between when the claim made with the incident that happen.

# %%
tsa_data['Day Differences'] = (tsa_data['Date Received'] - tsa_data['Incident Date']).dt.days

# %% [markdown]
# Lets try to visualize the distribution of the Day Differences with all the NaN just to be dropped first

# %%
import seaborn as sns

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,8))
sns.distplot(tsa_data[~tsa_data['Day Differences'].isna()]['Day Differences'])
plt.title('Day Differences Distribution')
# Out:
# Text(0.5,1,'Day Differences Distribution')

# %% [markdown]
# If we seen it from the plot, it seems there is days that less than 0 and even over than 1000. Lets try to visualize them both

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,8))
sns.distplot(tsa_data[(~tsa_data['Day Differences'].isna()) & (tsa_data['Day Differences'] <0)]['Day Differences'])
plt.title('Day Differences Distribution less than 0')
# Out:
# Text(0.5,1,'Day Differences Distribution less than 0')

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,8))
sns.distplot(tsa_data[(~tsa_data['Day Differences'].isna()) & (tsa_data['Day Differences'] >1000)]['Day Differences'])
plt.title('Day Differences Distribution less than 0')
# Out:
# Text(0.5,1,'Day Differences Distribution less than 0')

# %% [markdown]
# ## Question
#
# Why do you think there is day that way more than thousand days differences, and why some day differences are less than 0? (claim was made before the incident is like someone predicting a future after all).

# %% [markdown]
# ## Answer
#
# To properly answer the question above, I fell that I need to do some exploring first to gather enough data.

# %%
tsa_data_dropna = tsa_data.dropna()
tsa_more = tsa_data_dropna[tsa_data_dropna['Day Differences'] >1000]

# %%
tsa_more.head()
# Out:
#         Claim Number Date Received Incident Date Airport Code  \
# 10932  2004100464331    2004-09-09    2001-09-01          ORD
# 16208  2005061086208    2005-06-01    2002-04-30          FLL
# 20981  2006042505316    2006-04-13    2003-07-16          SEA
# 21876  2006062608536    2006-06-23    2003-06-07          COS
# 23508  2006111415554    2006-11-02    2000-10-23          JFK
#
#                                  Airport Name       Airline Name  \
# 10932    Chicago O'Hare International Airport  American Airlines
# 16208  Ft. Lauderdale-Hollywood International    Delta Air Lines
# 20981            Seattle-Tacoma International    Delta Air Lines
# 21876              Colorado Springs Municipal  American Airlines
# 23508           John F. Kennedy International    Delta Air Lines
#
#                     Claim Type       Claim Site  \
# 10932  Passenger Property Loss       Checkpoint
# 16208  Passenger Property Loss  Checked Baggage
# 20981  Passenger Property Loss       Checkpoint
# 21876          Property Damage  Checked Baggage
# 23508          Property Damage  Checked Baggage
#
#                                              Item Claim Amount    Status  \
# 10932  Clothing - Shoes; belts; accessories; etc.      $30.00   Approved
# 16208                                       Other     $487.00    Settled
# 20981                              Jewelry - Fine   $5;015.00     Denied
# 21876   Luggage (all types including footlockers)      $25.00     Denied
# 23508   Luggage (all types including footlockers)      $12.72   Approved
#
#       Close Amount      Disposition  Day Differences
# 10932      $30.00   Approve in Full           1104.0
# 16208     $243.50            Settle           1128.0
# 20981       $0.00              Deny           1002.0
# 21876       $0.00              Deny           1112.0
# 23508      $12.72   Approve in Full           2201.0

# %%
tsa_more.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 10932 to 36017
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Claim Number     16 non-null     object
#  1   Date Received    16 non-null     datetime64[ns]
#  2   Incident Date    16 non-null     datetime64[ns]
#  3   Airport Code     16 non-null     object
#  4   Airport Name     16 non-null     object
#  5   Airline Name     16 non-null     object
#  6   Claim Type       16 non-null     object
#  7   Claim Site       16 non-null     object
#  8   Item             16 non-null     object
#  9   Claim Amount     16 non-null     object
#  10  Status           16 non-null     object
#  11  Close Amount     16 non-null     object
#  12  Disposition      16 non-null     object
#  13  Day Differences  16 non-null     float64
# dtypes: datetime64[ns](2), float64(1), object(11)
# memory usage: 1.9+ KB

# %%
pd.DataFrame(tsa_more['Item'].value_counts().head())
# Out:
#                                             Item
# Other                                          3
# Currency                                       2
# Clothing - Shoes; belts; accessories; etc.     2
# Luggage (all types including footlockers)      2
# Medicines                                      1

# %%
pd.DataFrame(tsa_more['Airport Name'].value_counts().head())
# Out:
#                                              Airport Name
# Seattle-Tacoma International                            2
# Orlando International Airport                           1
# Erie International                                      1
# Baltimore/Washington Intl Thurgood Marshall             1
# Norman Y Mineta San Jose International                  1

# %%
pd.DataFrame(tsa_more['Airline Name'].value_counts().head())
# Out:
#                     Airline Name
# Delta Air Lines                5
# UAL                            4
# American Airlines              2
# USAir                          1
# Southwest Airlines             1

# %%
pd.DataFrame(tsa_more['Claim Type'].value_counts())
# Out:
#                          Claim Type
# Passenger Property Loss           9
# Property Damage                   5
# Passenger Theft                   1
# Personal Injury                   1

# %%
pd.DataFrame(tsa_more['Claim Site'].value_counts())
# Out:
#                  Claim Site
# Checked Baggage          10
# Checkpoint                6

# %%
pd.DataFrame(tsa_more['Claim Amount'].value_counts().head())
# Out:
#           Claim Amount
# $100.00              2
# $13.78               1
# $12.72               1
# $18.00               1
# $550.00              1

# %%
pd.DataFrame(tsa_more['Disposition'].value_counts())
# Out:
#                  Disposition
# Deny                      10
# Approve in Full            4
# Settle                     2

# %% [markdown]
# To properly answer the question above, first I feel that I need to explore the Internet just to make sure that this is still relatable to context. I found out that this site https://www.tsa.gov/travel/passenger-support/claims may help in order to give some understanding.
#
# From information collected from that site, it appears that the claims made within the 1000 days or more differences, might indicated that there are some difficulties regarding the claiming process, as from that site we can see that it normally took TSA up to six months to properly investigate the claims. It is more likely that difficulties can be caused by many factors, such as the details of problem, documentations, or many other variables.
#
# From above data, we can conclude that Clothing, Currency, and Luggage slightly have more cases than other claims. There are 9 claims for Property Lost and 5 claims for Property Damaged, where it mostly happened at Checked Baggage Claim Site with 10 cases. For Airport, there are 2 cases happened in the Seattle-Tacoma Airport, while in other airports there are just 1 case. Delta Airlines and United Airlines (UAL) have 5 & 4 cases respectively. This might indicated that claiming procedures in those categories mentioned above might have more difficulties than the other, whether in the identification, prove of belonging process or it might be just lost and found in many later days.
#
# Furthermore we can see that from 16 cases, there were 10 Denied cases in Disposition, this might be caused by the rate of Claim Amount filled, or inability to provide TSA with required information. In addition, it also indicated that the Seattle Airport and Delta Airlines might have more difficulties regarding the claiming procedures than other Airports and Airlines respectively, this is for example like tracing the lost item, property damage, etc. However if we compare it to the original data, and look at countplot below, I think that it is still within a tolerable amount as for example in 2004 there were at least 7000 reported cases, yet there is only 1 reported case within this category.

# %%
fig, ax= plt.subplots(1,2,figsize=(10,5))
sns.countplot(y = tsa_data['Date Received'].dt.year, ax=ax[0])
sns.countplot(y = tsa_more['Date Received'].dt.year, ax=ax[1])
ax[0].set_title('Total Reported Cases')
ax[1].set_title('More Than 1000 Days Cases')
plt.tight_layout()

# %% [markdown]
# Now we explore the claim that was made in less than 0 days differences.

# %%
tsa_less = tsa_data_dropna[tsa_data_dropna['Day Differences'] <0]

# %%
tsa_less.head()
# Out:
#        Claim Number Date Received Incident Date Airport Code  \
# 0          0909816M    2002-02-07    2003-01-06          MIA
# 621        0212060L    2003-02-12    2003-11-09          BOS
# 798   2004091362787    2003-03-04    2003-03-12          ATL
# 1011       0324011L    2003-03-24    2003-05-01          MCO
# 1130  2004042950167    2003-04-01    2004-03-17          MCO
#
#                                           Airport Name       Airline Name  \
# 0                          Miami International Airport  American Airlines
# 621               Boston (Logan) International Airport  American Airlines
# 798   Hartsfield-Jackson Atlanta International Airport    Delta Air Lines
# 1011                     Orlando International Airport    Delta Air Lines
# 1130                     Orlando International Airport  American Airlines
#
#                    Claim Type       Claim Site  \
# 0             Property Damage       Checkpoint
# 621   Passenger Property Loss       Checkpoint
# 798           Property Damage  Checked Baggage
# 1011  Passenger Property Loss  Checked Baggage
# 1130  Passenger Property Loss  Checked Baggage
#
#                                             Item Claim Amount    Status  \
# 0      Luggage (all types including footlockers)      $50.00   Approved
# 621   Clothing - Shoes; belts; accessories; etc.     $170.00   Approved
# 798    Luggage (all types including footlockers)     $259.95     Denied
# 1011   Luggage (all types including footlockers)     $400.00    Settled
# 1130                                       Other     $200.00    Settled
#
#      Close Amount      Disposition  Day Differences
# 0         $50.00   Approve in Full           -333.0
# 621      $170.00   Approve in Full           -270.0
# 798        $0.00              Deny             -8.0
# 1011     $200.00            Settle            -38.0
# 1130     $100.00            Settle           -351.0

# %%
tsa_less.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226 entries, 0 to 35991
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Claim Number     226 non-null    object
#  1   Date Received    226 non-null    datetime64[ns]
#  2   Incident Date    226 non-null    datetime64[ns]
#  3   Airport Code     226 non-null    object
#  4   Airport Name     226 non-null    object
#  5   Airline Name     226 non-null    object
#  6   Claim Type       226 non-null    object
#  7   Claim Site       226 non-null    object
#  8   Item             226 non-null    object
#  9   Claim Amount     226 non-null    object
#  10  Status           226 non-null    object
#  11  Close Amount     226 non-null    object
#  12  Disposition      226 non-null    object
#  13  Day Differences  226 non-null    float64
# dtypes: datetime64[ns](2), float64(1), object(11)
# memory usage: 26.5+ KB

# %%
pd.DataFrame(tsa_less['Item'].value_counts().head())
# Out:
#                                             Item
# Other                                         46
# Luggage (all types including footlockers)     31
# Clothing - Shoes; belts; accessories; etc.    22
# Jewelry - Fine                                16
# Locks                                         16

# %%
pd.DataFrame(tsa_less['Airport Name'].value_counts().head())
# Out:
#                                    Airport Name
# Newark International Airport                 12
# Phoenix Sky Harbor International             12
# Miami International Airport                  11
# Los Angeles International Airport            10
# LaGuardia                                     9

# %%
pd.DataFrame(tsa_less['Airline Name'].value_counts().head())
# Out:
#                       Airline Name
# American Airlines               33
# UAL                             30
# Continental Airlines            27
# Delta Air Lines                 26
# USAir                           24

# %%
pd.DataFrame(tsa_less['Claim Type'].value_counts())
# Out:
#                          Claim Type
# Passenger Property Loss         139
# Property Damage                  83
# Passenger Theft                   3
# Employee Loss (MPCECA)            1

# %%
pd.DataFrame(tsa_less['Claim Site'].value_counts())
# Out:
#                  Claim Site
# Checked Baggage         187
# Checkpoint               38
# Other                     1

# %%
pd.DataFrame(tsa_less['Claim Amount'].value_counts())
# Out:
#           Claim Amount
# $50.00               7
# $30.00               5
# $10.00               5
# $200.00              5
# $300.00              5
# ...                ...
# $196.00              1
# $409.11              1
# $64.19               1
# $677.43              1
# $29.00               1
#
# [176 rows x 1 columns]

# %%
pd.DataFrame(tsa_less['Disposition'].value_counts())
# Out:
#                  Disposition
# Deny                     131
# Approve in Full           54
# Settle                    41

# %% [markdown]
# With further analysis we can see that the claim that was made in less than 0 days differences, might indicated that there are some anomalies, such as a flaw in data input, data process, or events that aren't reported in this dataset.
#
# Now if we look carefully at the information provided above, first of all I think there are too many data to be considered a flaw. Out of 226 data in total, the Passenger Property Loss have 139 cases, where most cases by far happened at Checked Baggage Claim Site with 187 cases. We can also see that there are 22 cases happened in Newark International Airport, as well as in Phoenix Sky Harbor International. There are also 33 and 30 cases in American Airlines and United Airlines (UAL) respectively. Again, the many Denied cases in Disposition might be the same issue happened as in 1000 days or more differences.
#
# But in theory, considering that this is a record of a total 51066 data within 13 years span, a mere 226 data could possibly be a flaw. As shown in countplot below, for example if we see in 2004 there were over 7000 cases with only 50 cases recorded in this category. Although in the end we still couldn't figure out for sure what actually happened, but as far as we can go within this limited data, I personally think it's fair to conclude that this is the most logical answer.

# %%
fig, ax= plt.subplots(1,2,figsize=(10,5))
sns.countplot(y = tsa_data['Date Received'].dt.year, ax=ax[0])
sns.countplot(y = tsa_less['Date Received'].dt.year, ax=ax[1])
ax[0].set_title('Total Reported Cases')
ax[1].set_title('Less Than 0 Day Cases')
plt.tight_layout()

# %% [markdown]
# Remove the $ sign (some data need even more clean up by replacing the ; sign into . sign) from the Claim Amount columns and Close Amount columns, and change those columns datatype into float datatype

# %%
tsa_data["Claim Amount"] = tsa_data["Claim Amount"].str.replace('$', '')
tsa_data["Close Amount"] = tsa_data["Close Amount"].str.replace('$', '')

# %%
tsa_data["Claim Amount"] = tsa_data["Claim Amount"].str.replace(';', '')
tsa_data["Close Amount"] = tsa_data["Close Amount"].str.replace(';', '')

# %%
tsa_data['Claim Amount'] = tsa_data['Claim Amount'].apply(lambda x: float(x))
tsa_data['Close Amount'] = tsa_data['Close Amount'].apply(lambda x: float(x))

# %% [markdown]
# Create a new columns called Amount Differences by substract the Claim Amount with Close Amount columns

# %%
tsa_data['Amount Differences'] = tsa_data['Claim Amount'] - tsa_data['Close Amount']

# %%
tsa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51066 entries, 0 to 51065
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Claim Number        51066 non-null  object
#  1   Date Received       50996 non-null  datetime64[ns]
#  2   Incident Date       50496 non-null  datetime64[ns]
#  3   Airport Code        48915 non-null  object
#  4   Airport Name        48915 non-null  object
#  5   Airline Name        41470 non-null  object
#  6   Claim Type          49035 non-null  object
#  7   Claim Site          50817 non-null  object
#  8   Item                48918 non-null  object
#  9   Claim Amount        46886 non-null  float64
#  10  Status              47877 non-null  object
#  11  Close Amount        33786 non-null  float64
#  12  Disposition         32846 non-null  object
#  13  Day Differences     50460 non-null  float64
#  14  Amount Differences  33470 non-null  float64
# dtypes: datetime64[ns](2), float64(4), object(9)
# memory usage: 5.8+ MB

# %%
tsa_data.head()
# Out:
#   Claim Number Date Received Incident Date Airport Code  \
# 0     0909816M    2002-02-07    2003-01-06          MIA
# 1        14268    2002-06-20    2002-06-16          PHX
# 2        15242    2002-07-12    2002-05-31          BWI
# 3        16759    2002-08-21    2002-07-12          BWI
# 4        17846    2002-09-09    2002-08-30          BOS
#
#                                   Airport Name        Airline Name  \
# 0                  Miami International Airport   American Airlines
# 1             Phoenix Sky Harbor International                 NaN
# 2  Baltimore/Washington Intl Thurgood Marshall   American Airlines
# 3  Baltimore/Washington Intl Thurgood Marshall  Southwest Airlines
# 4         Boston (Logan) International Airport                 NaN
#
#                 Claim Type  Claim Site  \
# 0          Property Damage  Checkpoint
# 1          Property Damage  Checkpoint
# 2                      NaN       Other
# 3  Passenger Property Loss  Checkpoint
# 4          Property Damage  Checkpoint
#
#                                         Item  Claim Amount    Status  \
# 0  Luggage (all types including footlockers)         50.00  Approved
# 1                          Computer - Laptop       2270.09  Canceled
# 2  Luggage (all types including footlockers)        200.00    Denied
# 3                                      Other         21.44  Approved
# 4  Luggage (all types including footlockers)       1832.22  Canceled
#
#    Close Amount      Disposition  Day Differences  Amount Differences
# 0          50.0  Approve in Full           -333.0                0.00
# 1           NaN              NaN              4.0                 NaN
# 2           0.0             Deny             42.0              200.00
# 3          21.0  Approve in Full             40.0                0.44
# 4           0.0              NaN             10.0             1832.22

# %% [markdown]
# Lets try to visualize it again similar to the Day Differences feature, but this time we would use the Amount Differences feature (still just drop the NaN first)

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (8,8))
sns.distplot(tsa_data[(~tsa_data['Amount Differences'].isna())]['Amount Differences'])
plt.title('Amount Differences Distribution')
# Out:
# Text(0.5,1,'Amount Differences Distribution')

# %% [markdown]
# There is seems a differences in number that was way far. This time, lets use the Interquartile range (IQR) method to find the datapoint that seems to be an outlier based on the Amount Differences column, show the dataframe, and lets describe the Claim Amount and Close Amount column of the outlier dataframe based on the Amount Differences column

# %%
Q1 = tsa_data['Amount Differences'].describe()['25%']
Q3 = tsa_data['Amount Differences'].describe()['75%']
IQR = Q3 - Q1
Lower  = Q1 - 1.5*IQR
Upper = Q3 + 1.5*IQR

# %%
outlier = tsa_data[(tsa_data['Amount Differences'] < Lower) | (tsa_data['Amount Differences'] > Upper)]

# %%
outlier
# Out:
#         Claim Number Date Received       Incident Date Airport Code  \
# 4              17846    2002-09-09 2002-08-30 00:00:00          BOS
# 13             19133    2002-10-02 2002-08-22 00:00:00          CLE
# 21             18614    2002-10-17 2002-09-14 00:00:00          MCO
# 23             18356    2002-10-23 2002-09-18 00:00:00          LGA
# 27             21817    2002-10-29 2002-10-05 00:00:00          MCO
# ...              ...           ...                 ...          ...
# 36208  2009123167012    2009-12-29 2009-12-18 00:00:00          MIA
# 36210  2009123167017    2009-12-29 2009-12-02 15:30:00          JFK
# 36213  2010010867323    2009-12-29 2009-12-21 15:15:00          CVG
# 36225  2009123066912    2009-12-30 2009-12-15 00:00:00          GSO
# 36232  2010010567146    2009-12-30 2009-12-10 06:00:00          DFW
#
#                                      Airport Name              Airline Name  \
# 4            Boston (Logan) International Airport                       NaN
# 13                Cleveland Hopkins International        Northwest Airlines
# 21                  Orlando International Airport         American Airlines
# 23                                      LaGuardia                       NaN
# 27                  Orlando International Airport           Delta Air Lines
# ...                                           ...                       ...
# 36208                 Miami International Airport         American Airlines
# 36210               John F. Kennedy International  KLM Royal Dutch Airlines
# 36213  Cincinnati/Northern Kentucky International           Delta Air Lines
# 36225        Piedmont Triad International Airport           Delta Air Lines
# 36232     Dallas-Fort Worth International Airport         American Airlines
#
#                     Claim Type       Claim Site  \
# 4              Property Damage       Checkpoint
# 13                         NaN            Other
# 21             Property Damage       Checkpoint
# 23                         NaN       Checkpoint
# 27                         NaN            Other
# ...                        ...              ...
# 36208          Property Damage  Checked Baggage
# 36210  Passenger Property Loss  Checked Baggage
# 36213          Property Damage       Checkpoint
# 36225          Property Damage  Checked Baggage
# 36232          Property Damage       Checkpoint
#
#                                                     Item  Claim Amount  \
# 4              Luggage (all types including footlockers)       1832.22
# 13                                     Computer - Laptop       2000.00
# 21                                     Computer - Laptop       2000.00
# 23                                     Computer - Laptop       1801.99
# 27                                                 Other       7500.00
# ...                                                  ...           ...
# 36208                                                NaN       2200.00
# 36210  Clothing - Shoes; belts; accessories; etc.; Co...        900.00
# 36213                                  Computer - Laptop       1240.00
# 36225                                                NaN       2300.00
# 36232                                                NaN       3650.00
#
#          Status  Close Amount Disposition  Day Differences  Amount Differences
# 4      Canceled          0.00         NaN             10.0             1832.22
# 13       Denied          0.00        Deny             41.0             2000.00
# 21      Settled        600.00      Settle             33.0             1400.00
# 23      Settled        291.67      Settle             35.0             1510.32
# 27       Denied          0.00        Deny             24.0             7500.00
# ...         ...           ...         ...              ...                 ...
# 36208    Denied          0.00        Deny             11.0             2200.00
# 36210    Denied          0.00        Deny             26.0              900.00
# 36213    Denied          0.00        Deny              7.0             1240.00
# 36225    Denied          0.00        Deny             15.0             2300.00
# 36232    Denied          0.00        Deny             19.0             3650.00
#
# [4103 rows x 15 columns]

# %%
outlier['Claim Amount'].describe()
# Out:
# count    4.103000e+03
# mean     4.164579e+04
# std      1.954354e+06
# min      8.510100e+02
# 25%      1.214375e+03
# 50%      1.821750e+03
# 75%      3.000000e+03
# max      1.250000e+08
# Name: Claim Amount, dtype: float64

# %%
outlier['Close Amount'].describe()
# Out:
# count     4103.000000
# mean       114.613646
# std        686.521806
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      20000.000000
# Name: Close Amount, dtype: float64

# %% [markdown]
# It seems that Claim Amount feature really affecting lot of the differences that happen as 75% outlier data that in the Close Amount feature is still 0.
#
# ## Question
#
# I assume that many of this big differences happen because these people tend to request for bigger money than what it should be. Do you agree or disagree with my assumption (With an assumption that not outlier is have normal amount differences and outlier have a really big amount differences)? why? Try to explain it with the data

# %% [markdown]
# ## Answer
#
# It might be true. But in order to answer that question, we need to further breakdown the problem and the correlations between said variables.

# %%
non_outlier = tsa_data[~tsa_data['Amount Differences'].isin(outlier)]

# %%
non_outlier.head()
# Out:
#   Claim Number Date Received Incident Date Airport Code  \
# 0     0909816M    2002-02-07    2003-01-06          MIA
# 1        14268    2002-06-20    2002-06-16          PHX
# 2        15242    2002-07-12    2002-05-31          BWI
# 3        16759    2002-08-21    2002-07-12          BWI
# 4        17846    2002-09-09    2002-08-30          BOS
#
#                                   Airport Name        Airline Name  \
# 0                  Miami International Airport   American Airlines
# 1             Phoenix Sky Harbor International                 NaN
# 2  Baltimore/Washington Intl Thurgood Marshall   American Airlines
# 3  Baltimore/Washington Intl Thurgood Marshall  Southwest Airlines
# 4         Boston (Logan) International Airport                 NaN
#
#                 Claim Type  Claim Site  \
# 0          Property Damage  Checkpoint
# 1          Property Damage  Checkpoint
# 2                      NaN       Other
# 3  Passenger Property Loss  Checkpoint
# 4          Property Damage  Checkpoint
#
#                                         Item  Claim Amount    Status  \
# 0  Luggage (all types including footlockers)         50.00  Approved
# 1                          Computer - Laptop       2270.09  Canceled
# 2  Luggage (all types including footlockers)        200.00    Denied
# 3                                      Other         21.44  Approved
# 4  Luggage (all types including footlockers)       1832.22  Canceled
#
#    Close Amount      Disposition  Day Differences  Amount Differences
# 0          50.0  Approve in Full           -333.0                0.00
# 1           NaN              NaN              4.0                 NaN
# 2           0.0             Deny             42.0              200.00
# 3          21.0  Approve in Full             40.0                0.44
# 4           0.0              NaN             10.0             1832.22

# %% [markdown]
# Above are the dataframe for the non outlier data. I fell that I need to include this data into consideration, so we may get a through explanation for answering the question. That being said, first we'll try to see the correlation between variable, but before that we need to do a Goodness of Fit Test to determine whether it's a normally distributed data or not, so we can determine which proper correlation method to use.

# %%
from scipy.stats import anderson
def try_normal(data):
    result = {'Anderson' : {i:j for i,j in zip(anderson(data)[2], anderson(data)[1])}}
    result['Anderson']['stat'] = anderson(data)[0]
    return result

# %%
try_normal(non_outlier['Claim Amount'].dropna())
# Out:
# {'Anderson': {15.0: 0.576,
#   10.0: 0.656,
#   5.0: 0.787,
#   2.5: 0.918,
#   1.0: 1.092,
#   'stat': 18008.13274811356}}

# %%
try_normal(non_outlier['Close Amount'].dropna())
# Out:
# {'Anderson': {15.0: 0.576,
#   10.0: 0.656,
#   5.0: 0.787,
#   2.5: 0.918,
#   1.0: 1.092,
#   'stat': 10940.695195483575}}

# %%
try_normal(non_outlier['Amount Differences'].dropna())
# Out:
# {'Anderson': {15.0: 0.576,
#   10.0: 0.656,
#   5.0: 0.787,
#   2.5: 0.918,
#   1.0: 1.092,
#   'stat': 12861.006688797337}}

# %%
try_normal(outlier['Claim Amount'])
# Out:
# {'Anderson': {15.0: 0.575,
#   10.0: 0.655,
#   5.0: 0.786,
#   2.5: 0.917,
#   1.0: 1.091,
#   'stat': 1559.8322253694841}}

# %%
try_normal(outlier['Close Amount'])
# Out:
# {'Anderson': {15.0: 0.575,
#   10.0: 0.655,
#   5.0: 0.786,
#   2.5: 0.917,
#   1.0: 1.091,
#   'stat': 1244.9229604344491}}

# %%
try_normal(outlier['Amount Differences'])
# Out:
# {'Anderson': {15.0: 0.575,
#   10.0: 0.655,
#   5.0: 0.786,
#   2.5: 0.917,
#   1.0: 1.091,
#   'stat': 1559.9949476747934}}

# %% [markdown]
# From Goodness of Fit Test above, we can see that all the variables are not normally distributed. From here, I will measure the correlations between variables, in order to get some insight from the data.

# %%
non_outlier[['Claim Amount', 'Amount Differences']].corr('spearman')
# Out:
#                     Claim Amount  Amount Differences
# Claim Amount            1.000000            0.787883
# Amount Differences      0.787883            1.000000

# %%
outlier[['Claim Amount', 'Amount Differences']].corr('spearman')
# Out:
#                     Claim Amount  Amount Differences
# Claim Amount            1.000000            0.958133
# Amount Differences      0.958133            1.000000

# %%
outlier_dif = outlier['Claim Amount'].median() - outlier['Close Amount'].median()
non_outlier_dif = non_outlier['Claim Amount'].median() - non_outlier['Close Amount'].median()

# %%
print(f'outlier difference : {outlier_dif}''\n'
      f'Non Outlier difference : {non_outlier_dif}')
# Out:
# outlier difference : 1821.75
# Non Outlier difference : 113.50999999999999

# %% [markdown]
# Here we can see, we're using Spearman Correlation method since the data were not normally distributed. As we did some data exploration, we gathered some information from those correlation test. Clearly that the Claim Amount indeed have a strong correlation with Amount Differences, with 0.95 and 0.78 in both Outliers and Non Outliers data respectively. Thus, it probably means that the bigger the Claim Amount, the Amount Differences would also get bigger and vice-versa. For instance, theoritically this could mostly caused by many of Outlier's claims that were being denied by TSA (presented in barplot below). With that being said, we can conclude that the assumptions in above question might be proven correct as we can see that the difference in median of the Outliers are 1821.75, this is much bigger than the Non Outliers with only 113.50.

# %%
fig, ax= plt.subplots(1, 2, figsize=(8,5))
sns.barplot(outlier['Disposition'], outlier['Claim Amount'], data = outlier, ax=ax[0])
sns.barplot(outlier['Disposition'], outlier['Claim Amount'], data = non_outlier, ax=ax[1])
ax[0].set_title('Data Outlier')
ax[1].set_title('Data Non-Outlier')
plt.tight_layout()

# %% [markdown]
# ## Analysis
#
# We have try to cleaning some of the data that we have, and now we could try to done few analysis from the data we had. Try to answer this following question.
#
# ### Question
#
# 1. Is there Any relationship between the Airport and/or the Airline with the number of the claim that happen and the Claim Type? Also why is there a NaN in the Claim Type column?
#
# 1. If you realize, there is many different classes in the Status and Disposition column. What pattern you could find in these 2 columns because of this classes variation? is there any relation with the other columns?

# %% [markdown]
# ## Answer
#
# I'll try to answer this question starting by exploring and analyzing the original data.

# %%
tsa_data.head()
# Out:
#   Claim Number Date Received Incident Date Airport Code  \
# 0     0909816M    2002-02-07    2003-01-06          MIA
# 1        14268    2002-06-20    2002-06-16          PHX
# 2        15242    2002-07-12    2002-05-31          BWI
# 3        16759    2002-08-21    2002-07-12          BWI
# 4        17846    2002-09-09    2002-08-30          BOS
#
#                                   Airport Name        Airline Name  \
# 0                  Miami International Airport   American Airlines
# 1             Phoenix Sky Harbor International                 NaN
# 2  Baltimore/Washington Intl Thurgood Marshall   American Airlines
# 3  Baltimore/Washington Intl Thurgood Marshall  Southwest Airlines
# 4         Boston (Logan) International Airport                 NaN
#
#                 Claim Type  Claim Site  \
# 0          Property Damage  Checkpoint
# 1          Property Damage  Checkpoint
# 2                      NaN       Other
# 3  Passenger Property Loss  Checkpoint
# 4          Property Damage  Checkpoint
#
#                                         Item  Claim Amount    Status  \
# 0  Luggage (all types including footlockers)         50.00  Approved
# 1                          Computer - Laptop       2270.09  Canceled
# 2  Luggage (all types including footlockers)        200.00    Denied
# 3                                      Other         21.44  Approved
# 4  Luggage (all types including footlockers)       1832.22  Canceled
#
#    Close Amount      Disposition  Day Differences  Amount Differences
# 0          50.0  Approve in Full           -333.0                0.00
# 1           NaN              NaN              4.0                 NaN
# 2           0.0             Deny             42.0              200.00
# 3          21.0  Approve in Full             40.0                0.44
# 4           0.0              NaN             10.0             1832.22

# %%
pd.DataFrame(tsa_data['Claim Type'].value_counts())
# Out:
#                          Claim Type
# Passenger Property Loss       29713
# Property Damage               18590
# Personal Injury                 394
# Passenger Theft                 115
# Employee Loss (MPCECA)          114
# Motor Vehicle                    96
# Complaint                        13

# %%
pd.DataFrame(tsa_data['Airport Name'].value_counts().head())
# Out:
#                                       Airport Name
# John F. Kennedy International                 2286
# Los Angeles International Airport             1813
# Newark International Airport                  1747
# Chicago O'Hare International Airport          1712
# Orlando International Airport                 1633

# %%
pd.DataFrame(tsa_data['Airline Name'].value_counts().head())
# Out:
#                       Airline Name
# American Airlines             4377
# Delta Air Lines               4371
# UAL                           3507
# Southwest Airlines            3258
# Continental Airlines          2363

# %%
pd.DataFrame(tsa_data.groupby('Airport Name')['Claim Type'].value_counts().sort_values(ascending = False).head())
# Out:
#                                                            Claim Type
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss        1607
# Newark International Airport      Passenger Property Loss        1111
# Los Angeles International Airport Passenger Property Loss        1090
# Orlando International Airport     Passenger Property Loss        1056
# Miami International Airport       Passenger Property Loss         997

# %%
pd.DataFrame(tsa_data.groupby('Airline Name')['Claim Type'].value_counts().sort_values(ascending = False).head())
# Out:
#                                               Claim Type
# Airline Name         Claim Type
# Delta Air Lines      Passenger Property Loss        2665
# American Airlines    Passenger Property Loss        2646
# UAL                  Passenger Property Loss        2072
# Southwest Airlines   Passenger Property Loss        1955
# Continental Airlines Passenger Property Loss        1539

# %% [markdown]
# After gathering related informations let us check the correlation. I will use two methods to measure the association between these variables. Crammer's V and also using Spearman (factorized). we'll see if the differences affecting the correlation result, just to make a comparison between those two methods.

# %%
import scipy.stats as ss

# %%
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x,y)
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

# %%
cramers_v(tsa_data['Airport Name'], tsa_data['Claim Type'])
# Out:
# 0.2522217766994018

# %%
cramers_v(tsa_data['Airline Name'], tsa_data['Claim Type'])
# Out:
# 0.04264088575901359

# %%
tsa_data[['Airport Name','Claim Type']].apply(lambda x: x.factorize()[0]).corr('spearman')
# Out:
#               Airport Name  Claim Type
# Airport Name      1.000000    0.042477
# Claim Type        0.042477    1.000000

# %%
tsa_data[['Airline Name','Claim Type']].apply(lambda x: x.factorize()[0]).corr('spearman')
# Out:
#               Airline Name  Claim Type
# Airline Name       1.00000     0.11976
# Claim Type         0.11976     1.00000

# %%
tsa_data['Disposition'].value_counts()
# Out:
# Deny               17147
# Approve in Full     8727
# Settle              6972
# Name: Disposition, dtype: int64

# %%
tsa_data[['Item','Disposition', 'Amount Differences']].apply(lambda x: x.factorize()[0]).corr('spearman')
# Out:
#                         Item  Disposition  Amount Differences
# Item                1.000000    -0.388485           -0.333041
# Disposition        -0.388485     1.000000            0.830399
# Amount Differences -0.333041     0.830399            1.000000

# %%
tsa_data[(tsa_data['Status'] == 'Denied') | (tsa_data['Status'] == 'Approved') | (tsa_data['Status'] == 'Settled')][['Disposition','Status']].apply(lambda x: x.factorize()[0]).corr()
# Out:
#              Disposition    Status
# Disposition     1.000000  0.998848
# Status          0.998848  1.000000

# %% [markdown]
# Although we can see that from all cases reported, the highest number of claims for both Airport and Airlines are on Passenger Property Loss by 29713 cases. Where most reported cases happened on big airports, for example John F. Kennedy International, Los Angeles International, Newark International Airport, etc. For Airlines, 4377 cases reported in American Air Lines and 4371 cases reported on Delta Air Lines. While it looks like that there are some correlations between them, but from Crammer's and Spearman Correlation Test presented above, we can see that there is no strong correlation between Airline Name, Airport Name and Claim Type. For the Missing Values / NaN, I think that it might be the passengers intentionally or unintentionally didn't fill the Claim Type, or didn't specify it so TSA simply could not categorize these claims with their types.
# As for Disposition, there are a total of 17147 cases reported. Based on the correlation above, we found out that both Status of Claim and Disposition were affected by Amount Differences. Thus we can infer that maybe making an acceptable Claim Amount will increasing your chance of getting your claim Approved or Settled by TSA.

# %% [markdown]
# ## Bonus Question
#
# Could you find any interesting Insight from our data that you could explain? Try to explain it with the available data

# %% [markdown]
# ## Answer
#
# I think we can infer something out of this. I'll try to do a little trace back to our original data and try to bring up some of the interesting data found on the analysis above, to explain it below the data.

# %%
tsa_data.head()
# Out:
#   Claim Number Date Received Incident Date Airport Code  \
# 0     0909816M    2002-02-07    2003-01-06          MIA
# 1        14268    2002-06-20    2002-06-16          PHX
# 2        15242    2002-07-12    2002-05-31          BWI
# 3        16759    2002-08-21    2002-07-12          BWI
# 4        17846    2002-09-09    2002-08-30          BOS
#
#                                   Airport Name        Airline Name  \
# 0                  Miami International Airport   American Airlines
# 1             Phoenix Sky Harbor International                 NaN
# 2  Baltimore/Washington Intl Thurgood Marshall   American Airlines
# 3  Baltimore/Washington Intl Thurgood Marshall  Southwest Airlines
# 4         Boston (Logan) International Airport                 NaN
#
#                 Claim Type  Claim Site  \
# 0          Property Damage  Checkpoint
# 1          Property Damage  Checkpoint
# 2                      NaN       Other
# 3  Passenger Property Loss  Checkpoint
# 4          Property Damage  Checkpoint
#
#                                         Item  Claim Amount    Status  \
# 0  Luggage (all types including footlockers)         50.00  Approved
# 1                          Computer - Laptop       2270.09  Canceled
# 2  Luggage (all types including footlockers)        200.00    Denied
# 3                                      Other         21.44  Approved
# 4  Luggage (all types including footlockers)       1832.22  Canceled
#
#    Close Amount      Disposition  Day Differences  Amount Differences
# 0          50.0  Approve in Full           -333.0                0.00
# 1           NaN              NaN              4.0                 NaN
# 2           0.0             Deny             42.0              200.00
# 3          21.0  Approve in Full             40.0                0.44
# 4           0.0              NaN             10.0             1832.22

# %%
pd.DataFrame(tsa_data.groupby(['Airport Name','Claim Type']).count().sort_values('Claim Number',ascending=False).head())
# Out:
#                                                            Claim Number  \
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss          1607
# Newark International Airport      Passenger Property Loss          1111
# Los Angeles International Airport Passenger Property Loss          1090
# Orlando International Airport     Passenger Property Loss          1056
# Miami International Airport       Passenger Property Loss           997
#
#                                                            Date Received  \
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss           1606
# Newark International Airport      Passenger Property Loss           1111
# Los Angeles International Airport Passenger Property Loss           1089
# Orlando International Airport     Passenger Property Loss           1054
# Miami International Airport       Passenger Property Loss            996
#
#                                                            Incident Date  \
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss           1606
# Newark International Airport      Passenger Property Loss           1109
# Los Angeles International Airport Passenger Property Loss           1085
# Orlando International Airport     Passenger Property Loss           1056
# Miami International Airport       Passenger Property Loss            995
#
#                                                            Airport Code  \
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss          1607
# Newark International Airport      Passenger Property Loss          1111
# Los Angeles International Airport Passenger Property Loss          1090
# Orlando International Airport     Passenger Property Loss          1056
# Miami International Airport       Passenger Property Loss           997
#
#                                                            Airline Name  \
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss          1464
# Newark International Airport      Passenger Property Loss           997
# Los Angeles International Airport Passenger Property Loss           893
# Orlando International Airport     Passenger Property Loss           941
# Miami International Airport       Passenger Property Loss           869
#
#                                                            Claim Site  Item  \
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss        1605  1535
# Newark International Airport      Passenger Property Loss        1105  1079
# Los Angeles International Airport Passenger Property Loss        1089  1073
# Orlando International Airport     Passenger Property Loss        1053  1011
# Miami International Airport       Passenger Property Loss         994   958
#
#                                                            Claim Amount  \
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss          1424
# Newark International Airport      Passenger Property Loss          1029
# Los Angeles International Airport Passenger Property Loss          1047
# Orlando International Airport     Passenger Property Loss           993
# Miami International Airport       Passenger Property Loss           884
#
#                                                            Status  \
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss    1442
# Newark International Airport      Passenger Property Loss    1040
# Los Angeles International Airport Passenger Property Loss    1064
# Orlando International Airport     Passenger Property Loss    1002
# Miami International Airport       Passenger Property Loss     898
#
#                                                            Close Amount  \
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss           877
# Newark International Airport      Passenger Property Loss           751
# Los Angeles International Airport Passenger Property Loss           976
# Orlando International Airport     Passenger Property Loss           637
# Miami International Airport       Passenger Property Loss           613
#
#                                                            Disposition  \
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss          868
# Newark International Airport      Passenger Property Loss          748
# Los Angeles International Airport Passenger Property Loss          952
# Orlando International Airport     Passenger Property Loss          631
# Miami International Airport       Passenger Property Loss          605
#
#                                                            Day Differences  \
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss             1605
# Newark International Airport      Passenger Property Loss             1109
# Los Angeles International Airport Passenger Property Loss             1084
# Orlando International Airport     Passenger Property Loss             1054
# Miami International Airport       Passenger Property Loss              994
#
#                                                            Amount Differences
# Airport Name                      Claim Type
# John F. Kennedy International     Passenger Property Loss                 875
# Newark International Airport      Passenger Property Loss                 750
# Los Angeles International Airport Passenger Property Loss                 971
# Orlando International Airport     Passenger Property Loss                 636
# Miami International Airport       Passenger Property Loss                 612

# %%
pd.DataFrame(tsa_data.groupby(['Airline Name','Claim Type']).count().sort_values('Claim Number',ascending=False).head())
# Out:
#                                               Claim Number  Date Received  \
# Airline Name         Claim Type
# Delta Air Lines      Passenger Property Loss          2665           2664
# American Airlines    Passenger Property Loss          2646           2642
# UAL                  Passenger Property Loss          2072           2071
# Southwest Airlines   Passenger Property Loss          1955           1952
# Continental Airlines Passenger Property Loss          1539           1539
#
#                                               Incident Date  Airport Code  \
# Airline Name         Claim Type
# Delta Air Lines      Passenger Property Loss           2660          2633
# American Airlines    Passenger Property Loss           2641          2601
# UAL                  Passenger Property Loss           2069          2041
# Southwest Airlines   Passenger Property Loss           1952          1936
# Continental Airlines Passenger Property Loss           1535          1517
#
#                                               Airport Name  Claim Site  Item  \
# Airline Name         Claim Type
# Delta Air Lines      Passenger Property Loss          2633        2661  2576
# American Airlines    Passenger Property Loss          2601        2642  2580
# UAL                  Passenger Property Loss          2041        2071  2010
# Southwest Airlines   Passenger Property Loss          1936        1951  1879
# Continental Airlines Passenger Property Loss          1517        1536  1514
#
#                                               Claim Amount  Status  \
# Airline Name         Claim Type
# Delta Air Lines      Passenger Property Loss          2584    2620
# American Airlines    Passenger Property Loss          2565    2600
# UAL                  Passenger Property Loss          2012    2038
# Southwest Airlines   Passenger Property Loss          1888    1912
# Continental Airlines Passenger Property Loss          1519    1539
#
#                                               Close Amount  Disposition  \
# Airline Name         Claim Type
# Delta Air Lines      Passenger Property Loss          2383         2304
# American Airlines    Passenger Property Loss          2383         2303
# UAL                  Passenger Property Loss          1817         1709
# Southwest Airlines   Passenger Property Loss          1656         1612
# Continental Airlines Passenger Property Loss          1475         1440
#
#                                               Day Differences  \
# Airline Name         Claim Type
# Delta Air Lines      Passenger Property Loss             2659
# American Airlines    Passenger Property Loss             2637
# UAL                  Passenger Property Loss             2068
# Southwest Airlines   Passenger Property Loss             1949
# Continental Airlines Passenger Property Loss             1535
#
#                                               Amount Differences
# Airline Name         Claim Type
# Delta Air Lines      Passenger Property Loss                2376
# American Airlines    Passenger Property Loss                2377
# UAL                  Passenger Property Loss                1811
# Southwest Airlines   Passenger Property Loss                1652
# Continental Airlines Passenger Property Loss                1473

# %%
pd.DataFrame(tsa_data['Claim Type'].value_counts())
# Out:
#                          Claim Type
# Passenger Property Loss       29713
# Property Damage               18590
# Personal Injury                 394
# Passenger Theft                 115
# Employee Loss (MPCECA)          114
# Motor Vehicle                    96
# Complaint                        13

# %%
cramers_v(tsa_data['Airport Name'], tsa_data['Claim Type'])
# Out:
# 0.2522217766994018

# %%
cramers_v(tsa_data['Airline Name'], tsa_data['Claim Type'])
# Out:
# 0.04264088575901359

# %%
tsa_data[['Airport Name','Claim Type']].apply(lambda x: x.factorize()[0]).corr('spearman')
# Out:
#               Airport Name  Claim Type
# Airport Name      1.000000    0.042477
# Claim Type        0.042477    1.000000

# %%
tsa_data[['Airline Name','Claim Type']].apply(lambda x: x.factorize()[0]).corr('spearman')
# Out:
#               Airline Name  Claim Type
# Airline Name       1.00000     0.11976
# Claim Type         0.11976     1.00000

# %%
plt.figure(figsize = (11,5))
sns.countplot(x = tsa_data['Date Received'].dt.year)
plt.tight_layout()

# %%
tsa_data[tsa_data['Date Received'].dt.year==2002].sort_values(by = 'Date Received').head()
# Out:
#   Claim Number Date Received Incident Date Airport Code  \
# 0     0909816M    2002-02-07    2003-01-06          MIA
# 1        14268    2002-06-20    2002-06-16          PHX
# 2        15242    2002-07-12    2002-05-31          BWI
# 3        16759    2002-08-21    2002-07-12          BWI
# 4        17846    2002-09-09    2002-08-30          BOS
#
#                                   Airport Name        Airline Name  \
# 0                  Miami International Airport   American Airlines
# 1             Phoenix Sky Harbor International                 NaN
# 2  Baltimore/Washington Intl Thurgood Marshall   American Airlines
# 3  Baltimore/Washington Intl Thurgood Marshall  Southwest Airlines
# 4         Boston (Logan) International Airport                 NaN
#
#                 Claim Type  Claim Site  \
# 0          Property Damage  Checkpoint
# 1          Property Damage  Checkpoint
# 2                      NaN       Other
# 3  Passenger Property Loss  Checkpoint
# 4          Property Damage  Checkpoint
#
#                                         Item  Claim Amount    Status  \
# 0  Luggage (all types including footlockers)         50.00  Approved
# 1                          Computer - Laptop       2270.09  Canceled
# 2  Luggage (all types including footlockers)        200.00    Denied
# 3                                      Other         21.44  Approved
# 4  Luggage (all types including footlockers)       1832.22  Canceled
#
#    Close Amount      Disposition  Day Differences  Amount Differences
# 0          50.0  Approve in Full           -333.0                0.00
# 1           NaN              NaN              4.0                 NaN
# 2           0.0             Deny             42.0              200.00
# 3          21.0  Approve in Full             40.0                0.44
# 4           0.0              NaN             10.0             1832.22

# %%
tsa_data[tsa_data['Claim Amount']>100000].head()
# Out:
#      Claim Number Date Received Incident Date Airport Code  \
# 318      0718501M    2003-01-13           NaT          NaN
# 661      0221037L    2003-02-21    2003-01-08          LAS
# 1419     0428118L    2003-04-28    2003-03-15          GPT
# 3860     1217801M    2003-09-09    2003-02-28          FLL
# 3992     0916042M    2003-09-16    2003-07-07          IAH
#
#                                         Airport Name          Airline Name  \
# 318                                              NaN                   NaN
# 661                           McCarran International    Southwest Airlines
# 1419                   Gulfport-Biloxi International                   NaN
# 3860          Ft. Lauderdale-Hollywood International       Delta Air Lines
# 3992  Houston - George Bush Intercontinental Airport  Continental Airlines
#
#                    Claim Type       Claim Site  \
# 318                       NaN            Other
# 661   Passenger Property Loss  Checked Baggage
# 1419          Personal Injury       Checkpoint
# 3860          Personal Injury       Checkpoint
# 3992          Personal Injury       Checkpoint
#
#                                             Item  Claim Amount         Status  \
# 318                            Computer - Laptop      350000.0         Denied
# 661                                        Other      250000.0         Denied
# 1419                                         NaN     2000000.0         Denied
# 3860                                         NaN     2000000.0  In litigation
# 3992  Clothing - Shoes; belts; accessories; etc.      135000.0        Settled
#
#       Close Amount Disposition  Day Differences  Amount Differences
# 318            0.0        Deny              NaN            350000.0
# 661       250000.0        Deny             44.0                 0.0
# 1419           0.0        Deny             44.0           2000000.0
# 3860           NaN        Deny            193.0                 NaN
# 3992        9000.0      Settle             71.0            126000.0

# %%
pd.DataFrame(tsa_data['Claim Amount'].dropna().sort_values(ascending = False).head())
# Out:
#        Claim Amount
# 17190   125000000.0
# 27696    10000000.0
# 22010     5000000.0
# 32577     4000000.0
# 33704     2000000.0

# %% [markdown]
# There are many interesting pattern within this data aside from the 'less than 0 day differences' problem, which for me this is the most peculiar probblem, since I couldn't think that there is any possible reasons apart from considering this as a flaw data, unless that maybe my interpretations of this data & variable connected was wrong.
#
# But as we already know there are 51066 reported claim within 2002 through 2015. While most claim filled are of the Passenger Property Loss for 29713 cases. While 1607 of that reported on John F. Kennedy International, which as we know from the analysis before, as one of the biggest airport in USA, this Airport has the most reported cases of a total of 2286 claims filled against the TSA. Moreover from exploring the data we can see that 2665 claims filled by Delta Air Lines passengers, which also apparently is the 2nd most reported cases with a total of 4371 claims.
#
# Yet from the correlations measurement above, we could not see any strong correlations between those variable. And if we assume that this was a correct measurement, this might be an interesting find since if there are no strong correlations between them, we can consider that it might be just a coincidental.
#
# From the countplot above we see that in 2002, TSA only got 255 cases, and suddenly in 2003 they got a sudden spike in this category. Next year we can see that they got most claim filled at least according to this data. I've tried to search the Internet and I did found some interesting explanations, but I could not come out with an exact explanation for this.
#
# Although I don't know if this is caused by the lack of data or that this is the real case happened, since we only used 25% of the whole datasets, but for argument sake let's assume that this is a whole data so we can proceed this further. Aside from that they got the claims dropped sequentially by the next year. This might be a good thing for TSA, since the drop in this category means that they are getting better values in their service qualities.
#
# Also I need to point out that I found that while there are many claimed cases which the Claim Amount filled was 0, thus maybe they just want to notify TSA that something happened, I found it more interesting that there are 60 claimed cases with more than a million dollar Claim Amount, in fact the hight amount filled was 125 million dollars, while of course they mostly got denied the most interesting part of it that most of these belongs to the NaN Claim Type, which according to my assumptions before, they dind't actually specify it.

# %% [markdown]
# To create our dashboard, lets use only the data that was not outlier according to the Amount Differences. As we did not process all the NaN, just drop all those NaN. Save the file as 'tsa_claims_dashboard_ujian.csv', don't include the Index. As we don't want to have too much data in our dashboard, let's just sample 1000 data from our current data.
#
# Also, set the random seed to 101.

# %%
np.random.seed(101)

# %%
df = non_outlier.sample(1000).dropna()

# %%
df
# Out:
#         Claim Number Date Received Incident Date Airport Code  \
# 2991        0729154M    2003-07-29    2003-07-18          IND
# 25802  2007041924249    2007-04-19    2007-04-02          ORF
# 23908  2006121917382    2006-12-04    2006-11-13          FLL
# 8906   2004062256987    2004-05-27    2004-05-06          MSP
# 25648  2007041023667    2007-04-06    2006-12-28          JAX
# ...              ...           ...           ...          ...
# 30142  2008040942183    2008-04-01    2007-12-11          PHL
# 33521  2009031256167    2009-02-22    2009-01-16          SEA
# 665         0221032L    2003-02-21    2003-01-04          CLE
# 20672  2006033003839    2006-03-21    2006-01-04          YKM
# 29518  2007121136342    2008-02-11    2007-10-12          ABY
#
#                                      Airport Name          Airline Name  \
# 2991                   Indianapolis International     American Airlines
# 25802                       Norfolk International     American Airlines
# 23908      Ft. Lauderdale-Hollywood International              Jet Blue
# 8906   Minneapolis/ St.Paul International Airport    Northwest Airlines
# 25648                  Jacksonville International       Delta Air Lines
# ...                                           ...                   ...
# 30142          Philadelphia International Airport                   UAL
# 33521                Seattle-Tacoma International                   UAL
# 665               Cleveland Hopkins International  Continental Airlines
# 20672              Yakima Air Terminal-Mcallister           Horizon Air
# 29518  Southwest Georgia Regional Airport ;Albany       Delta Air Lines
#
#                     Claim Type       Claim Site  \
# 2991   Passenger Property Loss  Checked Baggage
# 25802          Property Damage       Checkpoint
# 23908  Passenger Property Loss  Checked Baggage
# 8906           Property Damage  Checked Baggage
# 25648  Passenger Property Loss       Checkpoint
# ...                        ...              ...
# 30142  Passenger Property Loss  Checked Baggage
# 33521  Passenger Property Loss  Checked Baggage
# 665            Property Damage  Checked Baggage
# 20672  Passenger Property Loss  Checked Baggage
# 29518  Passenger Property Loss       Checkpoint
#
#                                                     Item  Claim Amount  \
# 2991                                      Jewelry - Fine        180.00
# 25802                                 Cell Phones; Other        110.00
# 23908  Cameras - Digital; Cameras - Non-electronic (C...        510.00
# 8906           Luggage (all types including footlockers)         50.00
# 25648  Cosmetics - Perfume; toilet articles; medicine...        150.00
# ...                                                  ...           ...
# 30142                            Bedding - Other pillows        300.00
# 33521                                              Locks          7.29
# 665            Luggage (all types including footlockers)         55.00
# 20672                                              Other        325.00
# 29518                                              Other         87.00
#
#          Status  Close Amount      Disposition  Day Differences  \
# 2991    Settled         30.00           Settle             11.0
# 25802  Approved        110.00  Approve in Full             17.0
# 23908    Denied          0.00             Deny             21.0
# 8906   Approved         50.00  Approve in Full             21.0
# 25648  Approved        150.00  Approve in Full             99.0
# ...         ...           ...              ...              ...
# 30142    Denied          0.00             Deny            112.0
# 33521    Denied          0.00             Deny             37.0
# 665     Settled         27.50           Settle             48.0
# 20672    Denied          0.00             Deny             76.0
# 29518   Settled         17.11           Settle            122.0
#
#        Amount Differences
# 2991               150.00
# 25802                0.00
# 23908              510.00
# 8906                 0.00
# 25648                0.00
# ...                   ...
# 30142              300.00
# 33521                7.29
# 665                 27.50
# 20672              325.00
# 29518               69.89
#
# [447 rows x 15 columns]

# %%
df.to_csv('tsa_claims_dashboard_ujian.csv', index = False)

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqlconnector://root:Mysql123@localhost/tsa_ujian_cahya?host=localhost?port=3306')
conn = engine.connect()

# %%
result = conn.execute('select * from tsa_claims_ujian_dashboard').fetchall()

# %%
df2 = pd.DataFrame(result, columns = tsa_data.columns)

# %%
df2.isna().sum()
# Out:
# Claim Number          0
# Date Received         0
# Incident Date         0
# Airport Code          0
# Airport Name          0
# Airline Name          0
# Claim Type            0
# Claim Site            0
# Item                  0
# Claim Amount          0
# Status                0
# Close Amount          0
# Disposition           0
# Day Differences       0
# Amount Differences    0
# dtype: int64

# %% [markdown]
# Export the data to your SQL database, and try to connect the database to the dashboard
